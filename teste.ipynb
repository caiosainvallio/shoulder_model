# %%
import pandas as pd

# %%
features = pd.read_feather('artfacts/features_modelo.feather')

# %%
features[['index', 'mean', 'min', 'max']]
# Out:
#                                      index     mean   min    max
# 0                                    idade  56.7860  30.0   78.0
# 1                                    homen   0.4600   0.0    1.0
# 2                                 diabetes   0.1500   0.0    1.0
# 3                                       ar   0.0560   0.0    1.0
# 4                             ex_tabagista   0.1580   0.0    1.0
# 5                                tabagista   0.1060   0.0    1.0
# 6                                   trauma   0.1420   0.0    1.0
# 7                              trabalhista   0.1280   0.0    1.0
# 8                              infiltracao   0.1420   0.0    1.0
# 9                       supra_transfixante   0.8560   0.0    1.0
# 10                          supra_ret_m3cm   0.3220   0.0    1.0
# 11                              todo_supra   0.4480   0.0    1.0
# 12                          supra_anterior   0.8180   0.0    1.0
# 13  fucs_supra_media_infiltracao_gordurosa   0.1540   0.0    1.0
# 14  fucs_supra_muita_infiltracao_gordurosa   0.0580   0.0    1.0
# 15                           infra_parcial   0.0720   0.0    1.0
# 16                      infra_transfixante   0.2020   0.0    1.0
# 17                          infra_ret_m3cm   0.0960   0.0    1.0
# 18                 infra_extensao_superior   0.2300   0.0    1.0
# 19              infra_extensao_todo_tendao   0.0440   0.0    1.0
# 20  fucs_infra_media_infiltracao_gordurosa   0.1060   0.0    1.0
# 21  fucs_infra_muita_infiltracao_gordurosa   0.0480   0.0    1.0
# 22                    sub_extensao_parcial   0.3180   0.0    1.0
# 23             sub_extensao_terco_superior   0.1020   0.0    1.0
# 24               sub_extensao_transfixante   0.0600   0.0    1.0
# 25    fucs_sub_media_infiltracao_gordurosa   0.0680   0.0    1.0
# 26    fucs_sub_muita_infiltracao_gordurosa   0.0140   0.0    1.0
# 27                    biceps_lesao_parcial   0.1320   0.0    1.0
# 28                   biceps_lesao_completa   0.0620   0.0    1.0
# 29           biceps_estabilidade_subluxado   0.1420   0.0    1.0
# 30              biceps_estabilidade_luxado   0.0800   0.0    1.0
# 31                                 artrose   0.0780   0.0    1.0
# 32                                 asespre  41.5782   3.3  100.0

# %%
import pycaret.classification as caret
model = caret.load_model('artfacts/modelo_rf_pipeline')
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %%
model
# Out:
# Pipeline(memory=FastMemory(location=/tmp/joblib),
#          steps=[('numerical_imputer',
#                  TransformerWrapper(include=['Age', 'Biological_Sex_Male',
#                                              'Diabetes_Yes',
#                                              'Rheumatoid_arthritis_Yes',
#                                              'Past_Smoker', 'Current_Smoker',
#                                              'Previous_Trauma_Yes',
#                                              'Workers_Compensation_Yes',
#                                              'Previous_Injection_with_Corticosteroids_Yes',
#                                              'Supraspinatus_Thickness_Partial_tear',
#                                              'Supraspin...
#                  TransformerWrapper(transformer=FixImbalancer(estimator=BorderlineSMOTE()))),
#                 ('normalize', TransformerWrapper(transformer=StandardScaler())),
#                 ('actual_estimator',
#                  RandomForestClassifier(class_weight='balanced_subsample',
#                                         criterion='entropy', max_depth=10,
#                                         max_features=1.0,
#                                         min_impurity_decrease=0.005,
#                                         min_samples_leaf=3, min_samples_split=5,
#                                         n_estimators=130, n_jobs=-1,
#                                         random_state=1749))])
